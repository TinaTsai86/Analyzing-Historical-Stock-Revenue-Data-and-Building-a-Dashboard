# %% [markdown]
# QUESTION 1
#
# ![Screen Shot 2023-01-30 at 12.31.16 pm.png](attachment:e5ce4768-e751-4ecb-8cd8-7cfd23704eb0.png)

# %% [markdown]
# QUESTION 2
#
# ![Screen Shot 2023-01-30 at 12.49.39 pm.png](attachment:77c5a8a1-ff6f-4bb9-a66b-6702741449eb.png)

# %% [markdown]
# QUESTION 3
#
# ![Screen Shot 2023-01-30 at 1.04.30 pm.png](attachment:8a94d7b9-dd42-4ef2-becb-8248b0f379b5.png)

# %% [markdown]
# QUESTION 4
#
# ![Screen Shot 2023-01-30 at 1.16.01 pm.png](attachment:82b94e3d-709c-4a4f-bae9-a0a85eb601e4.png)

# %% [markdown]
# QUESTION 5
#
# ![Screen Shot 2023-01-30 at 1.16.46 pm.png](attachment:5d284d80-293c-43ae-ae10-be8ee97903b3.png)QUESTION 5
# ![Screen Shot 2023-01-30 at 1.17.20 pm.png](attachment:d08835bd-f4e0-4a9d-ad3f-55b91fdcbd04.png)

# %% [markdown]
# QUESTION 6
#
# ![Screen Shot 2023-01-30 at 1.18.27 pm.png](attachment:ded21298-542d-4521-a843-a3a0f8005fe2.png)
